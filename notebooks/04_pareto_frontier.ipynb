# %% [markdown]
# # Pareto Frontier (RQ3)
#
# Visualize tradeoffs:
# - Model size vs performance
# - Quantization vs performance
# - Latency vs performance
# - VRAM vs performance

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Results

# %%
# Load performance results
# Load efficiency benchmarks

# %% [markdown]
# ## Model Size vs Performance

# %%
# TODO: Scatter plot with Pareto frontier

# %% [markdown]
# ## Quantization vs Performance

# %%
# TODO: Compare FP16 vs INT8 vs INT4
