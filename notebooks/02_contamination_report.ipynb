# %% [markdown]
# # Contamination Report
#
# Analyze contamination detection results from Phase 0.
#
# Three-layer protocol:
# 1. Zero-shot audit
# 2. N-gram overlap
# 3. Min-K% probing

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Contamination Results

# %%
with open("../results/contamination/contamination_summary.json") as f:
    results = json.load(f)

# %% [markdown]
# ## Contamination Heatmap (Models × Tasks)

# %%
# TODO: Create heatmap showing which model-task pairs are contaminated

# %% [markdown]
# ## Per-Layer Analysis

# %%
# TODO: Show how many flagged by each layer
