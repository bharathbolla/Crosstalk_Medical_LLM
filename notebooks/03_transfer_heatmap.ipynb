# %% [markdown]
# # Transfer Matrix Heatmap (RQ4)
#
# Visualize 5×5 transfer matrix:
# - Entry [i,j] = performance on task j when also trained on task i
# - Identify negative transfer patterns
# - Correlate with task similarity

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.results.manager import ResultManager
from src.evaluation.transfer_analysis import (
    compute_transfer_matrix,
    detect_negative_transfer,
    predict_transfer_success,
)

# %% [markdown]
# ## Load Results

# %%
result_manager = ResultManager(results_dir=Path("../results"))

st_results = result_manager.load_all_results(strategy_filter=["S1"])
mt_results = result_manager.load_all_results(strategy_filter=["S3b"])

# %% [markdown]
# ## Compute Transfer Matrix

# %%
# TODO: Compute transfer matrix

# %% [markdown]
# ## Heatmap Visualization

# %%
# TODO: Create annotated heatmap

# %% [markdown]
# ## Negative Transfer Detection

# %%
# TODO: Identify task pairs with negative transfer
