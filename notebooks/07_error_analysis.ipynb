# %% [markdown]
# # Error Analysis
#
# Categorize errors into 6 categories:
# 1. Abbreviation errors
# 2. Negation scope errors
# 3. Discontiguous span errors
# 4. Rare entity errors
# 5. Temporal ambiguity errors
# 6. Cross-sentence reference errors

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import matplotlib.pyplot as plt

from src.evaluation.error_analysis import categorize_errors, ERROR_CATEGORIES

# %% [markdown]
# ## Load Predictions

# %%
# TODO: Load predictions and labels

# %% [markdown]
# ## Categorize Errors

# %%
# TODO: Run categorization

# %% [markdown]
# ## Error Distribution

# %%
# TODO: Bar plot of error categories
