# %% [markdown]
# # Data Exploration
#
# Explore the 5 SemEval tasks:
# - Dataset statistics (samples, tokens, label distributions)
# - Sequence length analysis
# - Label schema comparison
# - Vocabulary overlap

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.base import TaskRegistry
from src.evaluation.transfer_analysis import label_schema_similarity, vocabulary_overlap

# %% [markdown]
# ## Load Datasets

# %%
task_registry = TaskRegistry()
tasks = ["semeval2014t7", "semeval2015t14", "semeval2016t12", "semeval2017t3", "semeval2021t6"]

# %% [markdown]
# ## Dataset Statistics

# %%
# TODO: Compute statistics for each task

# %% [markdown]
# ## Sequence Length Distribution

# %%
# TODO: Plot histograms of sequence lengths

# %% [markdown]
# ## Label Schema Comparison

# %%
# TODO: Compute Jaccard similarity between all task pairs

# %% [markdown]
# ## Vocabulary Overlap

# %%
# TODO: Compute vocabulary overlap matrix
