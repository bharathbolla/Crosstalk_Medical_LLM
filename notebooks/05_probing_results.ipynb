# %% [markdown]
# # Probing Results
#
# Analyze what medical knowledge was learned in shared adapters.
#
# Four probes:
# 1. Medical concept type
# 2. Negation detection
# 3. Abbreviation expansion
# 4. Temporal ordering

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Probing Results

# %%
with open("../results/probing/probing_results.json") as f:
    results = json.load(f)

# %% [markdown]
# ## Compare Strategies

# %%
# TODO: Compare S1 vs S2 vs S3a vs S3b on all probes
